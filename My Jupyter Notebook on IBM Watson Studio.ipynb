# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Benjamin Mock** <br> I want to work as a business analyst for global company.

# %% [markdown]
# _I am interested in data science because this is one of the fastest devoloping industries and the job of the future. I want to be ahead of my fellow peers._

# %% [markdown]
# ### Calculation of simple numeric equation (1+1)

# %%
1+1

# %% [markdown]
# Don´t Worry, I got everything
#
# ***
# [This is a link to google](https://www.google.com)
#
# 1. First
# * Second
